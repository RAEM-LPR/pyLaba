# %% [markdown]
# # Визуализация массивов numpy

# %% [markdown]
# ## Изображения как массивы
# В компьютерной графике используется так называемое "растровое" представление изображения, которое представляет собой не что иное как матрицу "пикселей", каждый элемент которой является числовым кодом цвета. Массив numpy, имеющий подходящие размеры и подходящий тип данных, может быть визуализирован непосредственно как растровое изображение. Посмотрим простой пример.

# %%
import numpy as np
gradient = np.tile(np.arange(0, 256, dtype='uint8'), (255, 1))
gradient
# Out:
# array([[  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        ...,
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255]], dtype=uint8)

# %% [markdown]
# Стоит обратить внимание на тип данных - uint8. Это целое беззнаковое 8-битное число. Проще говоря, просто 1 байт. Именно такой тип используется для кодирования цвета (хотя библиотека matplotlib позволяет визуализировать массивы с любыми типами данных, но для некоторых других целей стоит использовать тип uint8). О функции `np.tile` почитайте подробнее в документации.

# %%
import matplotlib.pyplot as plt
plt.imshow(gradient, cmap='plasma', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# Визуализация массива в matplotlib выполняется с помощью функции imshow. Аргументы `cmap='gray', vmin=0, vmax=255` говорят о том, что должны использоваться оттенки серого со значениями от 0 (черный) до 255 (белый).

# %% [markdown]
# **Упраженение №1**
#
# Попробуйте поэкспериментировать с этими параметрами. Посмотреть встроенные цветовые схемы matplotlib можно здесь: https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
plt.imshow(gradient, cmap='plasma', vmin=100, vmax=255)
plt.show()

# %% [markdown]
# ## Загрузка растрового изображения в массив
# Воспользовавшись библиотекой pillow можно загрузить в массив растровое изображение.

# %%
from PIL import Image
img = Image.open('flowers.JPG')
img_arr = np.array(img)

# %%
img_arr.shape
# Out:
# (1182, 1773, 3)

# %% [markdown]
# Мы получили 3-мерный массив. Первые две оси - это высота и ширина изображения, третья ось содержит три компонента цвета - красный, синий и зеленый. Отобразить изображение можно тем же способом.

# %%
plt.imshow(img_arr)
plt.show()

# %% [markdown]
# Поскольку в данном случае мы имеем цветное изображение, параметр `cmap` указывать не нужно.

# %% [markdown]
# ## Обработка изображений

# %% [markdown]
# Попробуем применить к изображению (или, что то же самое, к массиву) некоторые из известных нам операций. Например, усреднение по третьей оси (т.е. по оси цвета) дает нам черно-белое изображение.

# %%
plt.imshow(img_arr.mean(axis=2), cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3288/108900523.py in <module>
#       1 plt.imshow(img_arr.mean(axis=2), cmap='gray')
# ----> 2 plt.show()
#
# /opt/rh/rh-python38/root/usr/local/lib64/python3.8/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     376     """
#     377     _warn_if_gui_out_of_main_thread()
# --> 378     return _backend_mod.show(*args, **kwargs)
#     379
#     380
#
# /opt/rh/rh-python38/root/usr/local/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# /opt/rh/rh-python38/root/usr/local/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py in _fetch_figure_metadata(fig)
#     229     if _is_transparent(fig.get_facecolor()):
#     230         # the background is transparent
# --> 231         ticksLight = _is_light([label.get_color()
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
#
# /opt/rh/rh-python38/root/usr/local/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py in <listcomp>(.0)
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
# --> 234                                 for label in axis.get_ticklabels()])
#     235         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     236             # there are one or more tick labels, all with the same lightness
#
# /opt/rh/rh-python38/root/usr/local/lib64/python3.8/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1230         if minor:
#    1231             return self.get_minorticklabels()
# -> 1232         return self.get_majorticklabels()
#    1233
#    1234     def get_majorticklines(self):
#
# /opt/rh/rh-python38/root/usr/local/lib64/python3.8/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1182     def get_majorticklabels(self):
#    1183         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1184         ticks = self.get_major_ticks()
#    1185         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1186         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# /opt/rh/rh-python38/root/usr/local/lib64/python3.8/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1357         while len(self.majorTicks) < numticks:
#    1358             # Update the new tick label properties from the old.
# -> 1359             tick = self._get_tick(major=True)
#    1360             self.majorTicks.append(tick)
#    1361             self._copy_tick_props(self.majorTicks[0], tick)
#
# /opt/rh/rh-python38/root/usr/local/lib64/python3.8/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2330         else:
#    2331             tick_kw = self._minor_tick_kw
# -> 2332         return YTick(self.axes, 0, major=major, **tick_kw)
#    2333
#    2334     def set_label_position(self, position):
#
# /opt/rh/rh-python38/root/usr/local/lib64/python3.8/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     485
#     486     def __init__(self, *args, **kwargs):
# --> 487         super().__init__(*args, **kwargs)
#     488         # x in axes coords, y in data coords
#     489         self.tick1line.set(
#
# /opt/rh/rh-python38/root/usr/local/lib64/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# /opt/rh/rh-python38/root/usr/local/lib64/python3.8/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     156             markeredgecolor=color, markersize=size, markeredgewidth=width,
#     157         )
# --> 158         self.tick2line = mlines.Line2D(
#     159             [], [],
#     160             color=color, linestyle="none", zorder=zorder, visible=tick2On,
#
# /opt/rh/rh-python38/root/usr/local/lib64/python3.8/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     395         # update kwargs before updating data to give the caller a
#     396         # chance to init axes (and hence unit support)
# --> 397         self.update(kwargs)
#     398         self.pickradius = pickradius
#     399         self.ind_offset = 0
#
# /opt/rh/rh-python38/root/usr/local/lib64/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#    1062                         raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                              f"has no property {k!r}")
# -> 1064                     ret.append(func(v))
#    1065         if ret:
#    1066             self.pchanged()
#
# /opt/rh/rh-python38/root/usr/local/lib64/python3.8/site-packages/matplotlib/artist.py in set_zorder(self, level)
#    1104             level = self.__class__.zorder
#    1105         self.zorder = level
# -> 1106         self.pchanged()
#    1107         self.stale = True
#    1108
#
# /opt/rh/rh-python38/root/usr/local/lib64/python3.8/site-packages/matplotlib/artist.py in pchanged(self)
#     365         remove_callback
#     366         """
# --> 367         self._callbacks.process("pchanged")
#     368
#     369     def is_transform_set(self):
#
# /opt/rh/rh-python38/root/usr/local/lib64/python3.8/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     264         called with ``*args`` and ``**kwargs``.
#     265         """
# --> 266         for cid, ref in list(self.callbacks.get(s, {}).items()):
#     267             func = ref()
#     268             if func is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# Можно визуализировать отдельно красный, зеленый и синий компоненты изображения.

# %%
ax1 = plt.subplot(131)
ax1.imshow(img_arr[:, :, 0], cmap='Reds_r')
ax2 = plt.subplot(132)
ax2.imshow(img_arr[:, :, 1], cmap='Greens_r')
ax3 = plt.subplot(133)
ax3.imshow(img_arr[:, :, 2], cmap='Blues_r')
plt.show()

# %% [markdown]
# С помощью срезов и транспонирования можно переворачивать изображение (при транспонировании нужно правильно указать оси, чтобы цвет остался без изменений).

# %%
ax1 = plt.subplot(221)
ax1.imshow(img_arr[::-1])
ax2 = plt.subplot(222)
ax2.imshow(img_arr[:, ::-1])
ax3 = plt.subplot(223)
ax3.imshow(img_arr[::-1, ::-1])
ax3 = plt.subplot(224)
ax3.imshow(np.transpose(img_arr, (1, 0, 2)))
plt.show()

# %% [markdown]
# С помощью некоторых математических функций можно производить обработку изображения. Например, увеличить красный компонент (преобразования типов необходимы, чтобы не выйти за пределы допустимых значений байта и не получить некрасивые искажения).

# %%
modified = img_arr.astype('float')
modified[:, :, 0] *= 1.5
modified[modified > 255] = 255
modified = modified.astype('uint8')
plt.imshow(modified)
plt.show()

# %% [markdown]
# Здесь стоит немного пояснить третью строчку. При применении к массивам логических операций мы получаем массив такого же размера, как исходный, но содержащий булевы значения.

# %%
a = np.array([1, 2, 3, 4])
a > 2

# %% [markdown]
# С другой стороны в качестве "индекса" для среза мы можем использовать массив булевых значений, который означает, какие элементы из исходного массива войдут в срез, а какие - нет.

# %%
a[[True, False, True, False]]

# %% [markdown]
# Соединяя эти два факта вместе мы получаем очень удобный способ фильтрации массива: в качестве индекса внутри квадратных скобок пишем логическое выражение, которое будет преобразовано в массив булевых значений, которые в свою очередь будут использваны в качестве индекса. Например, выберем из массива только четные элементы:

# %%
a[a % 2 == 0]

# %% [markdown]
# Вернемся к нашему примеру. Строка `modified[modified > 255] = 255` означает, что те элементы массива, значение которых оказалось больше, чем 255 (максимальное значение в 1 байте), мы ограничиваем значением 255, чтобы избежать переполнения.

# %% [markdown]
# **Упражнение №2**
#
# Поэкспериментируйте с этим примером. Попробуйте другие коэфициенты, другие компоненты цвета и другие математические операции.

# %%
modified = img_arr.astype('float')
modified1 = img_arr.astype('float')
modified[:, :, 0]=modified[:, :, 1]
modified[:, :, 1]=modified[:, :, 2]
modified[:, :, 2]=modified1[:, :, 0]

#modified[:, :, 1] *= 1.5
#modified[modified < 50] = 100
modified = modified.astype('uint8')
plt.imshow(modified)
plt.show()

# %% [markdown]
# ## Размытие изображения (задача)
# Перед вами стоит задача написать функцию размытия изображений. Размытие изображения - частный случай операции "свертки" (или "конволюции"), которая часто применяется и в других задачах. Не вникая глубоко в математические детали, можно сказать, что суть этой операции в том, что элементы исходного массива суммируются со своими соседями с определенным весом. Для большей ясности начнем с обычного 1-мерного массива. Пусть у нас есть массив (для простоты пусть в нем будет большая часть нулей и только один ненулевой элемент в середине), и мы хотим просто усреднить каждое значение с его ближайшими соседями. Тогда массив весов будет состоять из трех единиц (чтобы исходная сумма осталась неизменной, поделим их на 3). Воспользуемся функцией `convolve1d` из библиотеки `scipy`.

# %%
import scipy
import scipy.ndimage

# %%
a = np.array([0, 0, 10, 0, 0], dtype=float)
w = np.array([1/3, 1/3, 1/3])
scipy.ndimage.convolve1d(a, w)

# %% [markdown]
# Попробуем взять другой массив весов. Например, пусть исходное значение входит в среднее с несколько большим весом, чем его соседи.

# %%
a = np.array([0, 0, 10, 0, 0], dtype=float)
w = np.array([1/4, 1/2, 1/4])
scipy.ndimage.convolve1d(a, w)

# %% [markdown]
# Можно сделать свертку и большего размера.

# %%
a = np.array([0, 0, 0, 10, 0, 0, 0], dtype=float)
w = np.array([1/12, 1/6, 1/2, 1/6, 1/12])
scipy.ndimage.convolve1d(a, w)

# %%
Аналогично делаются и двумерные свёртки.

# %%
a = np.zeros((5, 5))
a[2, 2] = 10
a

# %%
w = np.array([[1, 2, 1], [2, 4, 2], [1, 2, 1]], dtype=float)
w /= w.sum()
scipy.ndimage.convolve(a[:], w)
a

# %% [markdown]
# **Упражнение №3**
#
# Напишите функцию размытия изображения с заданной весовой матрицей. При этом не забудьте учесть следующие детали:
# 1. Функция должна корректно работать как с цветными, так и с черно-белыми изображениями.
# 2. Весовая матрица, возможно, нуждается в нормировке.
# 3. В итоговом изображении не должно быть переполнения однобайтного типа.

# %%
aas=30
aa = [[6250000/(x*(aas-x)*y*(aas-y)+1) for x in range(aas)] for y in range(aas)]
np.array(aa)

# %%
def blur(img_array, weights_array):
    """
    Вычисляет свертку изображения и нормированной весовой матрицы.
    """
    weights_array /= weights_array.sum()
    blured = img_array.astype('float')   
    q1=scipy.ndimage.convolve(blured[:,:,0], weights_array)    
    q2=scipy.ndimage.convolve(blured[:,:,1], weights_array)   
    q3=scipy.ndimage.convolve(blured[:,:,2], weights_array)
    for i in range(len(blured)):
        for j in range(len(blured[0])):
            blured[i][j][0]=q1[i][j]
            blured[i][j][1]=q2[i][j]
            blured[i][j][2]=q3[i][j]
    
    """
    blured1 = blured.astype('float')
    blured[:, :, 0]=blured[:, :, 1]
    blured[:, :, 1]=blured[:, :, 2]
    blured[:, :, 2]=blured1[:, :, 0]
    """
    #blured[blured < 0xFF] = 0xFF
    blured = blured.astype('uint8')     
    plt.imshow(blured)
    plt.show()    
    pass

wa = np.array(aa,dtype=float)#np.array([[10, 1, 10], [10, 1, 10], [10, 1, 10]], dtype=float)
#wa=np.ones((10,10))
imgbufr=np.array(Image.open('flowers.JPG')).astype('uint8')
#bgimg = img_arr.mean(axis=2)

#print(gimg)
#plt.imshow(imgbufr)
#plt.show()

blur(imgbufr,wa)
#modified[modified < 50] = 100

# = modified.astype('uint8')

# %% [markdown]
# **Упражнение №4**
#
# Напишите функцию гауссова размытия. Функция принимает на вход дисперсию размытия (сигму), генерирует весовую матрицу и вызывает функцию из предыдущего задания.
#
# Функция гауссова распределения (нормировочный множитель можно опустить, поскольку матрица в любом случае будет нормироваться потом):
#
# $$
# f(x) = e^{-\frac{1}{2}(\frac{x}{\sigma})^2}
# $$
# где `x` - расстояние до центра.
#
# Подумайте, какого размера должна быть весовая матрица.

# %%
import math
def gaussian_blur(img_array, sigma):
    abc=round(max(5*sigma,3))
    idc=abc//2
    aaq=np.array([[ math.exp(-0.5*((x-idc)**2+(y-idc)**2)/(sigma)**2)for x in range(abc)] for y in range(abc)] )  
    """
    Выполняет гауссово размытие с заданной дисперсией
    """
    blur(img_array, aaq)
    pass

imgbufrgs=np.array(Image.open('flowers.JPG')).astype('uint8')
plt.imshow(imgbufrgs)
plt.show()
gaussian_blur(imgbufrgs,5)

# %%
np.array([[ math.exp(-0.5*((x-2)**2+(y-2)**2)/(0.5)**2) for x in range(5)] for y in range(5)] )
# Out:
# array([[1.12535175e-07, 4.53999298e-05, 3.35462628e-04, 4.53999298e-05,
#         1.12535175e-07],
#        [4.53999298e-05, 1.83156389e-02, 1.35335283e-01, 1.83156389e-02,
#         4.53999298e-05],
#        [3.35462628e-04, 1.35335283e-01, 1.00000000e+00, 1.35335283e-01,
#         3.35462628e-04],
#        [4.53999298e-05, 1.83156389e-02, 1.35335283e-01, 1.83156389e-02,
#         4.53999298e-05],
#        [1.12535175e-07, 4.53999298e-05, 3.35462628e-04, 4.53999298e-05,
#         1.12535175e-07]])

# %% [markdown]
# ## Генерирование изображений

# %% [markdown]
# В первом примере мы уже видели, как сгенерировать простой градиент. Давайте попробуем что-нибудь посложнее.

# %%
x = np.linspace(-0.5, 0.5, 1000)
y = x[::-1].reshape((-1, 1))
dist = np.sqrt(x ** 2 + y ** 2)
img = np.sin(1/dist)
plt.imshow(img, cmap='plasma')
plt.show()

# %%
x = np.linspace(-20, 20, 1000)
y = x[::-1].reshape((-1, 1))
dist = np.sqrt(x ** 2 + y ** 2)
img = np.sin(dist) * np.exp(-dist * 0.2)
plt.imshow(img)
plt.show()

# %% [markdown]
# Здесь в переменной `x` мы создали линейную последовательность точек по оси x, в переменной `y` - эту же последовательность, но расположенную вертикально (реверс сделан, чтобы ось y была направлена как обычно снизу вверх - строки в массивах нумеруются сверху вниз). Сложение двух массивов, один из которых представляет собой строку, а другой - столбец, дает матрицу попарных сумм их элементов.

# %%
a = np.array([1, 2, 3])
b = np.array([[10],
              [20],
              [30]])
a + b

# %% [markdown]
# С помощью этого приема легко одной операцией посчитать функцию двух переменных на некотором участке пространства. В данном случае мы посчитали затухающий синус.

# %% [markdown]
# **Упражнение №5**
# Изобразите функцию на диапазоне \[-3, 3]
# $$
# f(x, y) = x^2 + (y + 1 - \sqrt{|x|})^2 - 1
# $$

# %%
def funk533(x ,y):   
    return x**2+(y+1-(x**2)**0.25)**2-1

x = np.linspace(-3, 3, 1000)
y = x[::-1].reshape((-1, 1))
img = funk533(x,y)
plt.imshow(img, cmap='plasma')
plt.show()

# %% [markdown]
# Напоследок сделаем что-нибудь по-настоящему красивое. Например, множество Мандельброта. Напомним, что это множество точек `c` на комплексной плоскости такое, что последовательность
# $$
# z_{n} = z_{n-1}^2 + c
# $$
# задает ограниченную последовательность.
#
# На практике можно вычислить несколько итераций (скажем, 100), и если значение всё ещё меньше 2, можно считать, что в этой точке последовательность ограничена.
#
# Для начала создадим комплексную плоскость.

# %%
re = np.linspace(-2, 2, 200)
im = np.linspace(-2, 2, 200).reshape((-1, 1))
c = re + im * 1j

# %% [markdown]
# Теперь посчитаем последотельность. Можете не обращать внимания на предупреждение о переполнении - в некоторых точках последовательность уже ушла в бесконечность.

# %%
z = np.zeros((200, 200))
for i in range(100):
    z = z ** 2 + c

# %% [markdown]
# Наконец, изобразим получившееся множество.

# %%
img = np.zeros((200, 200))
img[np.abs(z) < 2] = 255
plt.imshow(img)
plt.show()

# %% [markdown]
# **Упражнение №6**
# Добавьте в это изображение оттенки в соответствии с тем, насколько быстро последовательность расходится в данной точке. Напишите функцию, в которой можно задать диапазон и количество точек ("качество" изображения).

# %%
def mandelbrot(x_low, x_high, y_low, y_high, points_x, points_y):
    """
    Создает изображение множества Мандельброта в диапазоне по x от x_low до x_high,
    по y - от y_low до y_high с разрешением points_x*points_y
    """
    re = np.linspace(x_low, x_high, points_x)
    im = np.linspace(y_low, y_high, points_y).reshape((-1, 1))
    c = re + im * 1j  
    z = np.zeros((points_x, points_y))   
    mandel=np.zeros((points_x, points_y))   
    #for i in range(100):
    #    z = z ** 2 + c
    for k in range(100):
        z = z ** 2 + c
        for i in range(points_x):
            for j in range(points_y):
                if (mandel[i][j]==0) and (np.abs(z[i][j])>2):
                    mandel[i][j]=k
    
    plt.imshow(mandel, cmap='plasma')
    plt.show()
    return mandel
    
#mandelbrot(-2,2,-2,2,300,300)
mm=mandelbrot(0,0.4,0.5,0.7,300,300)
# Out:
# /tmp/ipykernel_3288/4022753858.py:14: RuntimeWarning: overflow encountered in square
#   z = z ** 2 + c
# /tmp/ipykernel_3288/4022753858.py:14: RuntimeWarning: invalid value encountered in square
#   z = z ** 2 + c

# %% [markdown]
# **Упражнение №7 (дополнительное)**
#
# Изобразите [множество Жюлиа](https://ru.wikipedia.org/wiki/%D0%9C%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE_%D0%96%D1%8E%D0%BB%D0%B8%D0%B0).

# %%
qwq141=plt.subplot(141)
qwq141.imshow(mm, cmap='gnuplot')
qwq142=plt.subplot(142)
qwq142.imshow(mm, cmap='nipy_spectral')
qwq143=plt.subplot(143)
qwq143.imshow(mm, cmap='gist_stern')
qwq144=plt.subplot(144)
qwq144.imshow(mm, cmap='cividis')
plt.show()

# %%
#z**2+0,28+0,0113j#0.74543 + 0.11301i,
def julia(x_low, x_high, y_low, y_high, points_x, points_y):
    re = np.linspace(x_low, x_high, points_x)
    im = np.linspace(y_low, y_high, points_y).reshape((-1, 1))
    c = -0.8 + 0.156j#0.74543 + 0.11301#re + im * 1j  
    z = re + im * 1j  #np.zeros((points_x, points_y))   
    mandel=np.zeros((points_x, points_y))   
    #for i in range(100):
    #    z = z ** 2 + c
    for k in range(100):
        z = z ** 2 + c
        for i in range(points_x):
            for j in range(points_y):
                if (mandel[i][j]==0) and (np.abs(z[i][j])>2):
                    mandel[i][j]=k
    
    plt.imshow(mandel, cmap='plasma')
    plt.show()
    return mandel
    
#kk=julia(-2,2,-2,2,300,300)
#kk=julia(0,0.4,0.5,0.7,300,300)

# %%
kkk= julia(-2,2,-2,2,300,300)#-0.8 + 0.156

# %%
kkkk= julia(-2,2,-2,2,300,300)#0.285 + 0.01j

# %%
kkkkk= julia(-2,2,-2,2,300,300)#-0.0085 + 0.71j

# %%
kk=julia(-2,2,-2,2,300,300)#0.74543 + 0.11301j

# %%
plt.imshow(kk, cmap='plasma')
plt.show()

# %%
kkk= julia(-0.5,0.5,-0.5,0.5,300,300)
#plt.imshow(kkk, cmap='plasma')
#plt.show()

# %%
k4k= julia(-0.1,0,0.3,0.4,300,300)

# %%
k5k= julia(-0.2,0,0.35,0.37,300,300)
# Out:
# /tmp/ipykernel_3288/2574672172.py:11: RuntimeWarning: overflow encountered in square
#   z = z ** 2 + c
# /tmp/ipykernel_3288/2574672172.py:11: RuntimeWarning: invalid value encountered in square
#   z = z ** 2 + c

# %%
plt.imshow(kk, cmap='nipy_spectral')
plt.show()
plt.imshow(kkk, cmap='nipy_spectral')
plt.show()
plt.imshow(k4k, cmap='nipy_spectral')
plt.show()
plt.imshow(k5k, cmap='nipy_spectral')
plt.show()
